# %%
from collections import Counter
import sys

# %%
string = "..."

# %%
print(len(string))
print(sys.getsizeof(string))
# Out:
# 1854
# 1903

# %%
print(Counter(string))
# Out:
# Counter({'g': 127, 'I': 125, 'C': 87, 'G': 82, 'B': 79, 'b': 78, 'Z': 74, 'A': 65, 'l': 59, 'c': 53, 'd': 50, 'W': 49, 'm': 44, '0': 44, 'V': 43, 'y': 42, 'H': 41, '2': 40, 'h': 37, 'Y': 35, 'X': 34, 'a': 33, 'S': 29, 'R': 29, 'i': 27, '3': 27, 'v': 25, 'F': 25, '5': 24, 'U': 22, 'o': 19, 'n': 19, 'k': 19, 's': 19, 'p': 19, '1': 18, 'z': 18, '9': 17, 'w': 16, 'u': 16, 'K': 15, 'J': 15, '4': 15, 'x': 14, 'Q': 14, 'N': 14, 'L': 10, 'e': 10, 'M': 9, 't': 8, 'E': 5, '8': 5, 'j': 4, '6': 2, 'D': 1, 'q': 1, 'P': 1, 'T': 1, 'f': 1})

# %%
only_caps = ''.join([letter for letter in string if letter.isupper()])
only_caps
# Out:
# '...'

# %%
only_caps.count("CAICA")
# Out:
# 24

# %%
only_lower = ''.join([letter for letter in string if letter.islower()])
only_lower
# Out:
# '...'

# %%
left, right = 0, len(string)-1

while left < right:
    print(string[left], string[right])
    left += 1
    right -= 1
# Out:
# C A
# g I
# o g
# g A
# I C
# C I
# A g
# g A
# I C
# C I
# A g
# g o
# I g
# E C
# h K
# l k
# b S
# G e
# x 0
# v l
# L m
# A c
# o 1
# K N
# I W
# C Z
# A z
# g J
# I X
# C Z
# A i
# g l
# I 3
# C Y
# B o
# X 8
# Z 1
# S Z
# d h
# y x
# Z m
# S Z
# B f
# n V
# b G
# G a
# F 0
# k 9
# I V
# H Z
# l y
# v V
# d H
# S d
# d w
# y F
# Z 2
# S Q
# B v
# o k
# Z 2
# X a
# J p
# l d
# I 3
# Q L
# o n
# K J
# I 3
# C b
# A u
# g E
# I W
# C a
# A k
# g V
# I G
# C c
# B p
# S t
# Y W
# W a
# 1 3
# w 5
# I i
# G b
# h l
# h 9
# c y
# y L
# B 6
# i M
# Z H
# W c
# V 0
# u R
# I H
# G a
# Z g
# v o
# c T
# n M
# R g
# 1 A
# b C
# m I
# F g
# 0 A
# Z C
# S I
# B g
# 0 A
# b i
# y C
# B K
# l o
# e g
# H P
# B t
# l 9
# c 2
# m Y
# l u
# l A
# b X
# m b
# N h
# l J
# I H
# G Q
# V m
# 4 R
# c 3
# G Y
# 9 8
# u A
# Z y
# W Z
# 5 u
# 0 l
# a m
# W c
# F l
# s V
# I m
# G b
# d p
# y d
# b m
# 3 b
# d F
# 0 B
# a C
# C c
# B t
# v F
# d m
# m U
# V g
# y 0
# I C
# H I
# R g
# o A
# Z C
# S I
# ...
